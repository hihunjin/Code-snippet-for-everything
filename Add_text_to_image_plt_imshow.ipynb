# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/Add_text_to_image_plt_imshow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !wget https://thispersondoesnotexist.com/image -O 'image.png'
import matplotlib.pyplot as plt
import cv2
# Out:
# --2021-09-16 16:31:19--  https://thispersondoesnotexist.com/image
# Resolving thispersondoesnotexist.com (thispersondoesnotexist.com)... 104.21.3.164, 172.67.130.241, 2606:4700:3032::6815:3a4, ...
# Connecting to thispersondoesnotexist.com (thispersondoesnotexist.com)|104.21.3.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 474276 (463K) [image/jpeg]
# Saving to: ‘image.png’
#
# image.png           100%[===================>] 463.16K   992KB/s    in 0.5s
#
# 2021-09-16 16:31:20 (992 KB/s) - ‘image.png’ saved [474276/474276]

# %%
image = cv2.imread("image.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Add text

# %%
plt.text(800,800, 'text here! hii',color='r')

# show
plt.imshow(image)
