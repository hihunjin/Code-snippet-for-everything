# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/image_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data
from PIL import Image

# %%
np_image = data.astronaut()
display(Image.fromarray(np_image))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F5C67E19090>
