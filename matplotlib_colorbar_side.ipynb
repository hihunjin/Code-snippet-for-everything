# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/matplotlib_colorbar_side.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
out = np.random.rand(100,100)#1000
out3 = out * 100
print(out3.min(), out3.max())
# Out:
# 0.002929425841347033 99.99165048716189

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.imshow(out3, cmap='jet')
ticks = np.linspace(out3.min(), out3.max(), 10, endpoint=True)
plt.colorbar(
    ticks=ticks, 
    shrink=0.7,
)
plt.axis('off')
plt.savefig('hi.png')
