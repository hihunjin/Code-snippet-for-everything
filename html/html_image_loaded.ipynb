# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/html_image_loaded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !wget https://thispersondoesnotexist.com/image -O 'image.png'

# %%
import base64
data_uri = base64.b64encode(open('image.png', 'rb').read()).decode('utf-8')
img_tag = '<img src="data:image/png;base64,{0}">'.format(data_uri)
# print(img_tag)
with open('ex.html', 'w') as f:
    f.write(img_tag)

# %%
from IPython.core.display import HTML
name = 'ex.html'
HTML(name)
# Out:
# <img src="data:image/png;base64,...">
