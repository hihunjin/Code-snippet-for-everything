# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/display_image_IPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image, display

# %%
# %%capture
# !wget https://thispersondoesnotexist.com/image -O 'image.png'

# %%
display(Image('image.png'))
