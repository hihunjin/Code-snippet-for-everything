# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/rule_based_segmentation_watershed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://docs.opencv.org/4.x/water_coins.jpg
# Out:
# --2022-06-16 03:59:42--  https://docs.opencv.org/4.x/water_coins.jpg
# Resolving docs.opencv.org (docs.opencv.org)... 172.67.218.21, 104.21.24.86, 2606:4700:3034::ac43:da15, ...
# Connecting to docs.opencv.org (docs.opencv.org)|172.67.218.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16322 (16K) [image/jpeg]
# Saving to: ‘water_coins.jpg’
#
# water_coins.jpg     100%[===================>]  15.94K  --.-KB/s    in 0s
#
# 2022-06-16 03:59:42 (61.4 MB/s) - ‘water_coins.jpg’ saved [16322/16322]

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('water_coins.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(gray,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)

# %%
from PIL import Image
display(Image.fromarray(img))
display(Image.fromarray(thresh))
# Out:
# <PIL.Image.Image image mode=RGB size=252x312 at 0x7FB1F4F45B50>
# <PIL.Image.Image image mode=L size=252x312 at 0x7FB1F1DD9D90>
