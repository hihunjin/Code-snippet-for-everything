# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/pandas/rename_column.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/biostats.csv -O biostats.csv
# Out:
# --2022-03-30 04:48:07--  https://people.sc.fsu.edu/~jburkardt/data/csv/biostats.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.16.102
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.16.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 849 [text/csv]
# Saving to: ‘biostats.csv’
#
# biostats.csv        100%[===================>]     849  --.-KB/s    in 0s
#
# 2022-03-30 04:48:07 (143 MB/s) - ‘biostats.csv’ saved [849/849]

# %%
import pandas as pd
df = pd.read_csv('biostats.csv')

# %%
df
# Out:
#     Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 0   Alex         "M"      41              74              170
# 1   Bert         "M"      42              68              166
# 2   Carl         "M"      32              70              155
# 3   Dave         "M"      39              72              167
# 4   Elly         "F"      30              66              124
# 5   Fran         "F"      33              66              115
# 6   Gwen         "F"      26              64              121
# 7   Hank         "M"      30              71              158
# 8   Ivan         "M"      53              72              175
# 9   Jake         "M"      32              69              143
# 10  Kate         "F"      47              69              139
# 11  Luke         "M"      34              72              163
# 12  Myra         "F"      23              62               98
# 13  Neil         "M"      36              75              160
# ...

# %%
df.columns
# Out:
# Index(['Name', '     "Sex"', ' "Age"', ' "Height (in)"', ' "Weight (lbs)"'], dtype='object')

# %%
df.rename(columns={'     "Sex"': 'Sex'}, inplace=True)

# %%
df
# Out:
#     Name         Sex   "Age"   "Height (in)"   "Weight (lbs)"
# 0   Alex         "M"      41              74              170
# 1   Bert         "M"      42              68              166
# 2   Carl         "M"      32              70              155
# 3   Dave         "M"      39              72              167
# 4   Elly         "F"      30              66              124
# 5   Fran         "F"      33              66              115
# 6   Gwen         "F"      26              64              121
# 7   Hank         "M"      30              71              158
# 8   Ivan         "M"      53              72              175
# 9   Jake         "M"      32              69              143
# 10  Kate         "F"      47              69              139
# 11  Luke         "M"      34              72              163
# 12  Myra         "F"      23              62               98
# 13  Neil         "M"      36              75              160
# ...
