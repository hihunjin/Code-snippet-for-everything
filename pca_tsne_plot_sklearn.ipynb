# %% [markdown]
# <a href="https://colab.research.google.com/github/hihunjin/Code-snippet-for-everything/blob/main/pca_tsne_plot_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ex = np.random.normal(loc=0, scale=1, size=(1_000,100))
# ex = np.random.lognormal(mean=0, sigma=1, size=(1_000,100))
# ex = np.random.uniform(size=(1_000,100))

# %%
# ex = ex.flatten()
print(ex.mean(), ex.std())
# Out:
# 0.5000630584129148 0.2885416828208474

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

model = PCA(n_components=2)

# %%
model.fit(ex)
# Out:
# PCA(n_components=2)

# %%
print(model.explained_variance_ratio_)
print(model.singular_values_)
# Out:
# [0.01173004 0.0114355 ]
# [31.24891823 30.8540995 ]

# %%
y = model.transform(ex)

# %%
y.shape
# Out:
# (10000, 2)

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(y[:,0], y[:,1])

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE

model = TSNE(n_components=2,
             learning_rate='auto',
             init='random'
)

# %%
y = model.fit_transform(ex)

# %%
y.shape
# Out:
# (1000, 2)

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(y[:,0], y[:,1])
